# %% [markdown]
# <a href="https://colab.research.google.com/github/madhurima99/Rotten-Scripts/blob/WatermarkImages/Rotten-Scripts/Python/Watermark_Images/Watermark_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import required Image library
from PIL import Image, ImageDraw, ImageFont

#Create an Image Object from an Image
path = '/content/sky.jpg'
img = Image.open(path)
width, height = img.size

draw = ImageDraw.Draw(img)
text = "©Madhurima.photography"

font = ImageFont.truetype("/content/JMH Typewriter-Thin.ttf", 50)
textwidth, textheight = draw.textsize(text,font=font)

# calculate the x,y coordinates of the text
margin = 5
x = width - textwidth - margin
y = height - textheight - margin

# draw watermark in the bottom right corner
draw.text((x, y), text,font=font, fill ="white")
#img.show()

#Save watermarked image
img.save('watermark.png')

# %%
from IPython.display import Image
print("Watermaked image:")
Image('/content/watermark.png',width=500, height=300)
# Out:
# Watermaked image:

# %%
print("original image:")
Image('/content/sky.jpg',width=500, height=300)
# Out:
# original image:
